# %% [markdown]
# <a href="https://colab.research.google.com/github/yagoandres/dea_studies/blob/main/convertExcel2table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime
import os
file_path = "/content/drive/MyDrive/Colab Notebooks/20250914_DEA_EnergySecurityPaper2.xlsx"

i_installed_capacity_per_capita = pd.read_excel(file_path,sheet_name='I1-Installed Capacity Capita', nrows=21,  usecols= 'A:Y')
i_energy_diversification        = pd.read_excel(file_path,sheet_name='I2-Energy diversification HHI', nrows=21,  usecols= 'A:Y')
i_energy_import                 = pd.read_excel(file_path,sheet_name='I3-Energy import', nrows=21,  usecols= 'A:Y')
i_perc_renewable                = pd.read_excel(file_path, sheet_name='I4-%Renewable', nrows=21,  usecols= 'A:Y')

o_mwh_capita                    = pd.read_excel(file_path, sheet_name='O1-MWh capita', nrows=21,  usecols= 'A:Y')
o_gdp_capita                    = pd.read_excel(file_path, sheet_name='O2-GDP_capita', nrows=21,  usecols= 'A:Y')
o_electrification               = pd.read_excel(file_path, sheet_name='O3-Electrification', nrows=21,  usecols= 'A:Y')
o_carbon_intensity              = pd.read_excel(file_path, sheet_name='O4-carbon intensity', nrows=21,  usecols= 'A:Y')

# %%
# Rename the first column in each DataFrame to 'dmu' for merging
i_installed_capacity_per_capita.rename(columns={i_installed_capacity_per_capita.columns[0]: 'dmu'}, inplace=True)
#display(i_installed_capacity_per_capita.head())
i_energy_diversification.rename(columns={i_energy_diversification.columns[0]: 'dmu'}, inplace=True)
i_energy_import.rename(columns={i_energy_import.columns[0]: 'dmu'}, inplace=True)
i_perc_renewable.rename(columns={i_perc_renewable.columns[0]: 'dmu'}, inplace=True)

o_mwh_capita.rename(columns={o_mwh_capita.columns[0]: 'dmu'}, inplace=True)
o_gdp_capita.rename(columns={o_gdp_capita.columns[0]: 'dmu'}, inplace=True)
o_electrification.rename(columns={o_electrification.columns[0]: 'dmu'}, inplace=True)
o_carbon_intensity.rename(columns={o_carbon_intensity.columns[0]: 'dmu'}, inplace=True)

# %%
i_energy_export = i_energy_import * -1
i_energy_export.dmu = i_energy_import.dmu
display(i_energy_export.head())
# Out:
#          dmu        2000        2001        2002        2003        2004  \
# 0  Argentina   33.842833   44.465803   44.631023   40.307737   28.031842
# 1  Australia  117.602690  126.513620  130.624172  125.288697  125.872031
# 2     Brazil  -23.641203  -21.066972  -15.693066  -12.650434  -14.987125
# 3     Canada   50.614077   51.816521   54.799280   49.299761   50.423719
# 4      China   -2.754653   -0.307180   -1.479454   -2.810539   -5.902867
#
#          2005        2006        2007        2008  ...        2014  \
# 0   24.036959   18.716217    8.758409    6.261836  ...  -14.067810
# 1  131.074666  123.806910  127.764291  123.534610  ...  185.555789
# 2  -11.709392   -9.424874  -10.767270  -10.990324  ...  -14.281473
# 3   48.003293   50.456952   54.627407   52.835115  ...   66.764578
# 4   -5.618321   -6.973699   -7.964425   -8.653415  ...  -17.557385
#
#          2015        2016        2017        2018        2019        2020  \
# 0  -13.547781  -11.999369  -13.218915   -8.608755   -2.491677   -1.243273
# 1  197.386842  206.230251  205.706926  211.937722  226.593269  232.949923
# 2   -8.698139   -2.766563   -1.249305    0.709656    3.945802   11.049775
# 3   68.497367   69.187084   71.809818   74.973032   75.859503   79.800975
# 4  -16.721401  -19.205924  -20.428228  -21.669651  -22.277265  -23.025318
#
#          2021        2022        2023
# 0   -5.973853   -1.971472   -1.300000
# 1  227.942246  236.757246  208.482901
# 2    3.730516    7.189340   13.572125
# 3   85.554508   87.694979   87.191718
# 4  -21.742813  -20.745499  -22.820100
#
# [5 rows x 25 columns]

# %%
# Melt the dataframes to long format
i_installed_capacity_per_capita_melted = i_installed_capacity_per_capita.melt(id_vars='dmu', var_name='year', value_name='installed_capacity_per_capita')
#display(i_installed_capacity_per_capita_melted.head(25))
#print(i_installed_capacity_per_capita_melted.shape)
i_energy_diversification_melted = i_energy_diversification.melt(id_vars='dmu', var_name='year', value_name='energy_diversification')
i_energy_export_melted = i_energy_export.melt(id_vars='dmu', var_name='year', value_name='energy_export')

i_perc_renewable_melted = i_perc_renewable.melt(id_vars='dmu', var_name='year', value_name='percentage_renewable')

o_mwh_capita_melted = o_mwh_capita.melt(id_vars='dmu', var_name='year', value_name='mwh_capita')
o_gdp_capita_melted = o_gdp_capita.melt(id_vars='dmu', var_name='year', value_name='gdp_capita')
o_electrification_melted = o_electrification.melt(id_vars='dmu', var_name='year', value_name='electrification')
o_carbon_intensity_melted = o_carbon_intensity.melt(id_vars='dmu', var_name='year', value_name='carbon_intensity')

# %%
merged_df = pd.merge(i_installed_capacity_per_capita_melted, i_energy_diversification_melted, on=['dmu', 'year'], how='outer')
#display(merged_df.head())
#print(merged_df.shape)

# %%
#display(i_energy_export_melted.head())
#print(i_energy_export_melted.shape)
merged_df = pd.merge(merged_df, i_energy_export_melted, on=['dmu', 'year'], how='outer')
#display(merged_df.head())
#print(merged_df.shape)

# %%
# Merge the dataframes


merged_df = pd.merge(merged_df, i_perc_renewable_melted, on=['dmu', 'year'], how='outer')

merged_df = pd.merge(merged_df, o_mwh_capita_melted, on=['dmu', 'year'], how='outer')
merged_df = pd.merge(merged_df, o_gdp_capita_melted, on=['dmu', 'year'], how='outer')
merged_df = pd.merge(merged_df, o_electrification_melted, on=['dmu', 'year'], how='outer')
merged_df = pd.merge(merged_df, o_carbon_intensity_melted, on=['dmu', 'year'], how='outer')

# Select the desired columns
final_df = merged_df[['dmu', 'year', 'installed_capacity_per_capita',
                      'energy_diversification', 'energy_export', 'percentage_renewable',
                      'mwh_capita', 'gdp_capita', 'electrification', 'carbon_intensity']]

# Display the resulting DataFrame
display(final_df.head())
#df2 = final_df.iloc[:100]
#print(df2)
# Out:
#          dmu  year  installed_capacity_per_capita  energy_diversification  \
# 0  Argentina  2000                          0.720             4114.315134
# 1  Argentina  2001                          0.745             4016.492525
# 2  Argentina  2002                          0.743             4154.941646
# 3  Argentina  2003                          0.741             4108.333120
# 4  Argentina  2004                          0.738             4037.284172
#
#    energy_export  percentage_renewable  mwh_capita   gdp_capita  \
# 0      33.842833                11.557    0.002396  7637.014892
# 1      44.465803                15.036    0.002583  7141.475077
# 2      44.631023                15.335    0.002697  2569.699635
# 3      40.307737                13.613    0.002863  3320.477751
# 4      28.031842                11.465    0.002837  4242.020991
#
#    electrification  carbon_intensity
# 0             95.7         355.47310
# 1             95.5         302.08563
# 2             96.1         294.83392
# 3             96.3         316.38970
# 4             96.5         357.67004

# %%
print(final_df.shape)
# Out:
# (480, 10)

# %%
# Out:
# 0      2000
# 1      2001
# 2      2002
# 3      2003
# 4      2004
#        ...
# 475    2019
# 476    2020
# 477    2021
# 478    2022
# 479    2023
# Name: year, Length: 480, dtype: object

# %%
final_df_2014 = final_df[final_df['year'] == 2014]
display(final_df_2014)
# Out:
#                 dmu  year  installed_capacity_per_capita  \
# 14        Argentina  2014                          0.881
# 38        Australia  2014                          2.078
# 62           Brazil  2014                          0.544
# 86           Canada  2014                          3.908
# 110           China  2014                          1.006
# 134            EU27  2014                          1.736
# 158          France  2014                          1.787
# 182         Germany  2014                          2.181
# 206           India  2014                          0.186
# 230       Indonesia  2014                          0.155
# 254           Italy  2014                          1.460
# 278           Japan  2014                          2.022
# 302          Mexico  2014                          0.607
# 326          Russia  2014                          1.731
# 350    Saudi Arabia  2014                          3.778
# 374    South Africa  2014                          0.866
# 398     South Korea  2014                          1.619
# 422          Turkey  2014                          0.873
# 446  United Kingdom  2014                          1.347
# 470   United States  2014                          3.361
#
#      energy_diversification  energy_export  percentage_renewable  mwh_capita  \
# 14              3794.220973     -14.067810                10.396    0.003288
# 38              4460.109549     185.555789                 5.663    0.010496
# 62              4316.643494     -14.281473                37.566    0.002951
# 86              3916.466444      66.764578                27.026    0.018324
# 110             5615.278555     -17.557385                 9.690    0.004175
# 134             1881.543230     -63.669640                14.118    0.006375
# 158             6092.567214     -47.903750                 9.885    0.008754
# 182             2518.528853     -64.035236                12.840    0.007604
# 206             5829.264441     -36.565941                 6.829    0.000962
# 230             3382.223800     123.004442                 4.708    0.000918
# 254             2062.908772     -78.388047                18.517    0.004558
# 278             3121.409941     -95.569045                 6.604    0.008336
# 302             3705.694452       7.934259                 6.426    0.002532
# 326             3304.455504      83.491415                 5.531    0.007343
# 350             5023.364531     172.635168                 0.004    0.011318
# 374             8168.289013      12.861095                 0.810    0.004582
# 398             3191.921884     -86.869391                 1.259    0.010692
# 422             3481.089962     -78.733473                 9.501    0.003229
# 446             2270.362849     -49.743168                 8.506    0.005212
# 470             2690.113620     -11.696750                 7.015    0.012677
#
#        gdp_capita  electrification  carbon_intensity
# 14   12233.144412            100.0         424.13745
# 38   62544.087377            100.0         734.18134
# 62   12274.993969             99.7         192.93880
# 86   50960.843117            100.0         188.86014
# 110   7781.065975            100.0         693.72760
# 134  35592.887488            100.0         369.34964
# 158  43148.045929            100.0          52.19756
# 182  48971.082472            100.0         521.68085
# 206   1553.883961             85.1         741.50310
# 230   3441.068085             97.0         691.58880
# 254  36028.349402            100.0         379.23553
# 278  38475.395246            100.0         591.52930
# 302  11391.377351             99.2         525.59920
# 326  14055.472656            100.0         449.28590
# 350  27805.485032            100.0         692.56550
# 374   6856.731371             85.9         791.60780
# 398  29252.931238            100.0         493.63410
# 422  12165.220135            100.0         567.25543
# 446  47426.620983            100.0         462.87863
# 470  55153.394018            100.0         529.40790

# %%
#pd.options.display.max_columns = None
#pd.options.display.max_rows = 1000
display(final_df)
# Out:
#                dmu  year  installed_capacity_per_capita  \
# 0        Argentina  2000                          0.720
# 1        Argentina  2001                          0.745
# 2        Argentina  2002                          0.743
# 3        Argentina  2003                          0.741
# 4        Argentina  2004                          0.738
# ..             ...   ...                            ...
# 475  United States  2019                          3.563
# 476  United States  2020                          3.590
# 477  United States  2021                          3.644
# 478  United States  2022                          3.691
# 479  United States  2023                          3.732
#
#      energy_diversification  energy_export  percentage_renewable  mwh_capita  \
# 0               4114.315134      33.842833                11.557    0.002396
# 1               4016.492525      44.465803                15.036    0.002583
# 2               4154.941646      44.631023                15.335    0.002697
# 3               4108.333120      40.307737                13.613    0.002863
# 4               4037.284172      28.031842                11.465    0.002837
# ..                      ...            ...                   ...         ...
# 475             2479.147185       0.899140                 8.967    0.012311
# 476             2493.455951       3.968160                10.123    0.011911
# 477             2402.799279       4.193233                10.116    0.012211
# 478             2411.586045       6.501101                10.875    0.012552
# 479             2550.276601       8.351910                11.212    0.012385
#
#        gdp_capita  electrification  carbon_intensity
# 0     7637.014892             95.7         355.47310
# 1     7141.475077             95.5         302.08563
# 2     2569.699635             96.1         294.83392
# 3     3320.477751             96.3         316.38970
# 4     4242.020991             96.5         357.67004
# ..            ...              ...               ...
# 475  65227.956591            100.0         439.40912
# 476  64401.507435            100.0         411.69820
# 477  71307.401728            100.0         423.74120
# 478  77860.911291            100.0         410.36740
# 479  82304.620427            100.0         392.84800
#
# [480 rows x 10 columns]

# %%
final_df.to_csv("/content/drive/MyDrive/Colab Notebooks/20250914_DEA_EnergySecurityPaper2.csv")
